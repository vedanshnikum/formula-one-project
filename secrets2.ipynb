# %%
import os

os.environ["AWS_ACCESS_KEY_ID"] = dbutils.secrets.get("f1-secrets", "AWS_ACCESS_KEY_ID")
os.environ["AWS_SECRET_ACCESS_KEY"] = dbutils.secrets.get("f1-secrets", "AWS_SECRET_ACCESS_KEY")
os.environ["KAGGLE_API_TOKEN"] = dbutils.secrets.get("f1-secrets", "KAGGLE_API_TOKEN")

S3_BUCKET = "f1-dp-vn"
AWS_REGION = "us-east-2"
