# %% [markdown]
# # General Silver Transforms
# > Runs universal transforms on every Bronze table
# > then dispatches per-table fix notebooks for tables with custom logic.

# %%
# %run /Workspace/Repos/nikum.vedansh@gmail.com/formula-one-project/scripts/utils/general_transforms_utils

# %%
# %run /Workspace/Repos/nikum.vedansh@gmail.com/formula-one-project/scripts/utils/specific_transforms_utils

# %%
# %run /Workspace/Repos/nikum.vedansh@gmail.com/formula-one-project/scripts/utils/universal_utils

# %%
data = spark.catalog.listTables(f"formone.bronze")

# %%
for table in data:
    df = spark.table(f"formone.bronze.{table.name}")
    df = apply_general_silver_transforms(df, table.name)
    df = apply_specific_silver_transforms(df, table.name)

    df = df.withColumn("transformed_at", F.current_timestamp())
    send_to_schema(df, table.name, "silver")

# %%
# %skip
# %sql
DROP SCHEMA formone.silver CASCADE;
CREATE SCHEMA formone.silver
