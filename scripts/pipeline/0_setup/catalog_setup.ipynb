-- %%
CREATE CATALOG IF NOT EXISTS formone;
USE CATALOG formone;

CREATE SCHEMA IF NOT EXISTS formone.bronze;
CREATE SCHEMA IF NOT EXISTS formone.silver;
CREATE SCHEMA IF NOT EXISTS formone.gold;
CREATE SCHEMA IF NOT EXISTS formone.dashboard;
CREATE VOLUME IF NOT EXISTS formone.bronze.checkpoints;
